# %%
import subprocess
import numpy as np
from pathlib import Path

# %%
path = str(Path.cwd())
word2vec = "./word2vec.sh"
sizes = [50, 100, 200]
windows = [3, 5, 20]
iters = [5, 10, 20]
cbow = [0, 1]

# %%
for size in sizes:
    for window in windows:
        for iter in iters:
            for c in cbow:
                params = {
                    "output": f"output/size{size}_window{window}_iter{iter}_cbow{c}.txt",
                    "size": str(size),
                    "window": str(window),
                    "iter": str(iter),
                    "cbow": str(c),
                }
                print(f"Train with:")
                print(f"Size: {size}")
                print(f"Window: {window}")
                print(f"Iter: {iter}")
                print(f"cbow: {c}")
                print("-" * 50)
                w2v = subprocess.run(
                    [
                        word2vec,
                        params["output"],
                        params["size"],
                        params["window"],
                        params["iter"],
                        params["cbow"],
                    ],
                    stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE,
                    text=True,
                    shell=True,
                )
# Out:
# Train with:
# Size: 50
# Window: 3
# Iter: 5
# cbow: 0
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 3
# Iter: 5
# cbow: 1
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 3
# Iter: 10
# cbow: 0
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 3
# Iter: 10
# cbow: 1
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 3
# Iter: 20
# cbow: 0
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 3
# Iter: 20
# cbow: 1
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 5
# Iter: 5
# cbow: 0
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 5
# Iter: 5
# cbow: 1
# --------------------------------------------------
# Train with:
# Size: 50
# Window: 5
# Iter: 10
# cbow: 0
# --------------------------------------------------
# ...

# %%
input = path + "/questions-words.txt"
output = path + "/output.txt"

# %%
words = {}
with open(output, "r") as f:
    line = f.readline()
    n_words, n_dim = line.split()
    n_words, n_dim = int(n_words), int(n_dim)
    for i in range(n_words):
        line = f.readline()
        word, vector = line.split(" ", 1)
        vector = np.fromstring(vector, sep=" ")
        words[word] = vector

# %%
def cosine_distance(u, v):
    uv = np.dot(u, v)
    u_norm = np.linalg.norm(u)
    v_norm = np.linalg.norm(v)
    return 1 - (uv / (u_norm * v_norm))

# %%
groups = {}

with open(input, "r") as f:
    line = f.readline()
    line = line.strip()
    while line:
        if line.startswith(":"):
            group = line[1:]
            groups[group] = []
            line = f.readline()
            line = line.strip()
            continue
        word1, word2, word3, word4 = line.split()
        word1_vector = words[word1]
        word2_vector = words[word2]
        word3_vector = words[word3]
        word4_vector = words[word4]
        result = word1_vector + word2_vector - word3_vector
        groups[group].append(cosine_distance(result, word4_vector))
        line = f.readline()
        line = line.strip()
    print(groups)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 14
#      12     continue
#      13 word1, word2, word3, word4 = line.split()
# ---> 14 word1_vector = words[word1]
#      15 word2_vector = words[word2]
#      16 word3_vector = words[word3]
#
# KeyError: 'Athens'

# %%
for group in groups:
    rmse = np.sqrt(np.mean(np.array(groups[group]) ** 2))
    print(f"{group}: {rmse}")
# Out:
#  capital-common-countries: 0.5912988021836282
#  capital-world: 0.7478531520667946
#  currency: 0.5445503361759875
#  city-in-state: 0.3551369722674706
#  family: 0.1337023023277771
#  gram1-adjective-to-adverb: 0.368709798833023
#  gram2-opposite: 0.2259190695993418
#  gram3-comparative: 0.5207957852624633
#  gram4-superlative: 0.5695730680913801
#  gram5-present-participle: 0.5017567768272787
#  gram6-nationality-adjective: 0.5467042377715985
#  gram7-past-tense: 0.49941388296007655
#  gram8-plural: 0.2779733295354481
#  gram9-plural-verbs: 0.4502998423604318
